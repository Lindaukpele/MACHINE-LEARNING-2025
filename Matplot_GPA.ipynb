# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("gpa.csv")
df
# Out:
#      high_GPA  univ_GPA
# 0        3.45      3.52
# 1        2.78      2.91
# 2        2.52      2.40
# 3        3.67      3.47
# 4        3.24      3.47
# ..        ...       ...
# 100      3.76      3.64
# 101      3.49      3.42
# 102      3.07      3.25
# 103      2.19      2.76
# 104      3.46      3.41
#
# [105 rows x 2 columns]

# %%
df.describe()
# Out:
#          high_GPA    univ_GPA
# count  105.000000  105.000000
# mean     3.076381    3.172857
# std      0.516598    0.447194
# min      2.030000    2.080000
# 25%      2.670000    3.010000
# 50%      3.170000    3.290000
# 75%      3.480000    3.470000
# max      4.000000    3.810000

# %%
df.mean()
# Out:
# high_GPA    3.076381
# univ_GPA    3.172857
# dtype: float64

# %%
df.mode()
# Out:
#    high_GPA  univ_GPA
# 0      3.28      3.28
# 1      3.42       NaN

# %%
df.std()
# Out:
# high_GPA    0.516598
# univ_GPA    0.447194
# dtype: float64

# %%
df.corr()
# Out:
#           high_GPA  univ_GPA
# high_GPA  1.000000  0.779563
# univ_GPA  0.779563  1.000000

# %%
#Return unique values in a column 
df["high_GPA"].unique()
# Out:
# array([3.45, 2.78, 2.52, 3.67, 3.24, 2.1 , 2.82, 2.36, 2.42, 3.51, 3.48,
#        2.14, 2.59, 3.46, 3.68, 3.91, 3.72, 2.15, 2.48, 3.09, 2.71, 2.46,
#        3.32, 3.61, 3.82, 2.64, 2.19, 3.34, 3.56, 3.81, 3.92, 4.  , 3.15,
#        3.22, 2.29, 2.03, 3.14, 3.52, 2.91, 2.83, 2.65, 2.41, 2.54, 2.66,
#        3.21, 2.84, 2.74, 2.24, 3.44, 2.89, 2.67, 3.29, 3.87, 3.94, 3.42,
#        3.41, 3.28, 3.62, 2.92, 2.81, 3.11, 2.7 , 2.62, 3.9 , 3.12, 2.09,
#        3.17, 3.02, 3.06, 2.76, 3.19, 2.23, 3.76, 3.49, 3.07])

# %%
#Determine number of unique values by counting the length of the returned string
len(df["high_GPA"].unique())
# Out:
# 75

# %%
#Determine the number of unique values by using the built in size function
df["high_GPA"].unique().size
# Out:
# 75

# %% [markdown]
# Dimesionality Reduction

# %%
#import visualization libraries
import matplotlib.pyplot as plt

# %%
import seaborn as sn

# %%
#Create a canvas and make a heatmap using the correlation between the variables
plt.figure(figsize=(10,5))
sn.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
# Basic Scatter plot
import matplotlib.pyplot as plt
plt.scatter(df["high_GPA"],df["univ_GPA"])
plt.show()

# %%
plt.scatter(df["high_GPA"],df["univ_GPA"], color="purple")
plt.title("Predicting University Grades \n from High School GPA", size = 15)
plt.xlabel("High School (GPA)")
plt.ylabel("University (GPA)")
plt.show()

# %%
#Create a histogram of the distribution of the grades
plt.hist(df)
plt.show()

# %%
# Add additional chart features
years = ["High School", "University"]

plt.figure(figsize=(12,4))
plt.hist(df, label = years, bins = 20)
plt.title("Distribution of School Grades", size = 15)
plt.xlabel("Grade Point Average")
plt.ylabel("Count")
plt.legend(loc='upper right', frameon=False)

# %%
# Create box plots with the Seaborn Library

import seaborn as sn
plt.figure(figsize=(12,6))
sn.boxplot(df)       #OR sn.boxplot(data = df)
# Out:
# <Axes: >

# %%
# Create violin plots with the Seaborn Library - these give additional 
# insight into the behaviour of the dataset.

plt.figure(figsize=(12,6))
sn.violinplot(data = df, palette=("husl")) #OR rocket, pastel, flare, husl, for the color palette  
# modify colour palette: https://seaborn.pydata.org/tutorial/color_palettes.html
# Out:
# <Axes: >

# %%
# Create a Pair Plot of all the attribute columns to quickly visualize the relationships 
# instead of making many individual scatter plots

sn.pairplot(df)

# %%
import matplotlib.pyplot as plt
x=[1,4,3,2,5,6]
y=[7,4,2,3,8,1]
plt.plot(x, y)
plt.show()

# %%
x=[1,2,3,4,5,6]
y=[7,4,2,3,8,1]
plt.figure(figsize=(12,6))
plt.bar(x, y)
plt.xlabel("Price")
plt.ylabel("Quantity")
plt.show()

# %%
x=[1,2,3,4,5,6]
y=[7,4,2,3,8,1]
plt.scatter(x, y)
plt.show()

# %%
x=[1,2,3,4,5,6]
y=[7,4,2,3,8,1]
plt.hist2d(x, y)
plt.show()

# %% [markdown]
# Data Points

# %%
#Basic scatter plot
import matplotlib.pyplot as plt
x1 = 2
y1 = 21
point_1 = [x1, y1]

# %%
#upper plot made using (x1, y1)
plt.scatter(x1, y1)
plt.show()

#lower plot made using the data extracted from the point
plt.scatter(point_1[0], point_1[1])
plt.show()

#These two plots show the exact same thing because the data is the same

# %%
#Value X Corresponds to the x-axis (horizontal) and y value corresponds to y-axis (vertical axis)
#plt.scatter(x1, y1)  OR
plt.scatter(point_1[0], point_1[1])
plt.xlabel("Horizontal Axis - Independent Variable")
plt.ylabel("Vertical Axis - Dependent Variable")
plt.xlim(0,3)   #shows limit of x axis from 0 to 3
plt.ylim(0,30)   #shows limit of y axis from 0 to 30

plt.show()    #Forces the notebook to show the output

# %%
#Lets say we have a data set
#X Measurements:
x1 = 2
x2 = 3
x3 = 4
x4 = 5
x5 = 2.5

#y Measurements:
y1 = 21
y2 = 32
y3 = 39
y4 = 50
y5 = 24

x_values = [x1, x2, x3, x4, x5]
y_values = [y1, y2, y3, y4, y5]

print("x-values = ", x_values, "\ny-values = ", y_values)
# Out:
# x-values =  [2, 3, 4, 5, 2.5]
# y-values =  [21, 32, 39, 50, 24]

# %%
plt.scatter(x_values, y_values)
plt.xlabel("Horizontal Axis - Independent Variable")
plt.ylabel("Vertical Axis - Dependent Variable")
plt.xlim(0,6), plt.ylim(0,60)

plt.show()

# %%
#Thwew is a relationship. When the value of x is increased, so is the value of y. Therefore, we can say that the y value is dependent on the x value. In this case, 
#...because it looks like we could draw a line straight through all points, we could also say that it is highly, linearly positively correlated.

# %%
plt.scatter(x_values, y_values)
plt.plot(range(1,7,1), range(10,70,10), color = 'red')  # Draws a line to show the relationship. range starts at 1, stop at 7 increasing by 1 i.e 1,7,1
plt.xlabel("Independent Variable (x)")
plt.ylabel("Dependent Variable (y)")
plt.xlim(0,6), plt.ylim(0,60)

plt.show()

# %% [markdown]
# We can also plot negative numbers on a scatter plot

# %%
x_values = [-9, -2, 0, 4, 9]
y_values = [8, 4, 0, -5, -8]

plt.axhline(color = 'black'), plt.axvline(color = 'black')
plt.scatter(x_values, y_values, s = 100)
plt.xlabel("Independent Variable (x)")
plt.ylabel("Dependent Variable (y)")
plt.xlim(-10,10), plt.ylim(-10,10)
# Out:
# ((-10.0, 10.0), (-10.0, 10.0))

# %%
#Adding the trend line helps us make predictions of where new data could fir in our relationship.

plt.axhline(color = 'black'), plt.axvline(color = 'black')
plt.scatter(x_values, y_values, s = 100)
plt.plot([-9.5,9.5], [9.5,-9.5], color = 'red')     #why did we use square bracket here instead of range as the previous??????????
plt.xlabel("Independent Variable (x)")
plt.ylabel("Dependent Variable (y)")
plt.xlim(-10,10), plt.ylim(-10,10)
# Out:
# ((-10.0, 10.0), (-10.0, 10.0))

# %%
plt.axhline(color = 'black'), plt.axvline(color = 'black')
plt.scatter(x_values, y_values, s = 100)
plt.plot([-9.5,9.5], [9.5,-9.5], color = 'red')     #why did we use square bracket here instead of range as the previous??????????
plt.scatter(6, -6, s = 100, color = 'green')
plt.plot([6,6], [-6,-10], color = 'green'), plt.plot([-10,6], [-6,-6], color = 'green')
plt.xlabel("Independent Variable (x)")
plt.ylabel("Dependent Variable (y)")
plt.xlim(-10,10), plt.ylim(-10,10)
# Out:
# ((-10.0, 10.0), (-10.0, 10.0))

# %% [markdown]
# We can do one better and actually calculate hte line of best fit instead of eyeballing it.

# %%
#fine line of best fit
import numpy as np
x_values = np.array([-9,-2,0,4,9])

m, b = np.polyfit(x_values, y_values,1)
#fits is y = mx + b formula

# %%
plt.axhline(color = 'black'), plt.axvline(color = 'black')
plt.scatter(x_values, y_values, s = 100)
plt.xlabel("Independent Variable (x)")
plt.ylabel("Dependent Variable (y)")
plt.xlim(-10,10), plt.ylim(-10,10)
plt.plot(x_values, m*x_values+b, color = 'red', linestyle = '--', linewidth=2)

# %%
#To calculate the actual estimate of the new object with measurement x = 6

x_new = 6
y_new = m*x_new+b
print(y_new)  #pretty close to our eyeball estimate!
# Out:
# -5.503311258278145

# %% [markdown]
# In machine learning, many methods try and find an equation of a line (or hhigher order equation) to estimate new values like we just did here, but in much more complex datasets.
#
#     for example, this dataset has 3 variables: x y & z

# %%
ax = plt.axes(projection='3d') #specifically creates a 3D axis named 'ax'
ax.set_xlabel('Independent Variable (x)')
ax.set_ylabel('Independent Variable (y)')
ax.set_zlabel('Dependent Variable (z)')

#Create and plot x, y, z data
plt.scatter(range(0,10,1), range(1,100,10), range(0,1000,100))

# %%
#Create histogram of the distribution of the grades

plt.hist(df)
plt.show()
years = ['High School', 'University]

plt.figure(figuresie=(12,4)
plt.hist(df, label = years, bins = 20)
plt.title('Distribution of School Grades', size = 15)
plt.xlabel('Grade Point Average')
plt.ylabel('Count')
plt.legend(loc='upper left', frameon=False)
# Out:
#   Cell In[80], line 5
#     years = ['High School', 'University]
#                             ^
# SyntaxError: unterminated string literal (detected at line 5)
