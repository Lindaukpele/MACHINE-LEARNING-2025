# %% [markdown]
# <h1><center> Module 2 - Lesson 1 - Introduction to Data <br> (and the Pandas Library) </center></h1>
#
# #### An Introduction:
#
# ---
# - Using pandas to load csv files
# - Base pandas functionality
# - Indexing and slicing dataframes
# - Creating dataframes from existing dataframes
# - Group-by functions
# - Concatenate and join dataframes
#
# - Website: https://pandas.pydata.org/

# %% [markdown]
# ## We will look at the Mushroom Dataset
# Link: https://www.kaggle.com/uciml/mushroom-classification

# %%
# Remove the hashtag in the line below and install the Pandas library if required
#pip install pandas

# %%
# Import the pandas library

import pandas as pd

# %%
# Read the mushroom csv file downloaded from Kaggle into a dataframe called 'df'

df =  pd.read_csv("mushrooms.csv")

# %%
# View the dataframe

df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0               c         n          k  ...                        s
# 1               c         b          k  ...                        s
# 2               c         b          n  ...                        s
# 3               c         n          n  ...                        s
# 4               w         b          k  ...                        s
# ...           ...       ...        ...  ...                      ...
# 8119            c         b          y  ...                        s
# 8120            c         b          y  ...                        s
# 8121            c         b          n  ...                        s
# 8122            c         n          b  ...                        k
# 8123            c         b          y  ...                        s
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                         w                      w         p          w
# 1                         w                      w         p          w
# 2                         w                      w         p          w
# 3                         w                      w         p          w
# 4                         w                      w         p          w
# ...                     ...                    ...       ...        ...
# 8119                      o                      o         p          o
# 8120                      o                      o         p          n
# 8121                      o                      o         p          o
# 8122                      w                      w         p          w
# 8123                      o                      o         p          o
#
#      ring-number ring-type spore-print-color population habitat
# 0              o         p                 k          s       u
# 1              o         p                 n          n       g
# 2              o         p                 n          n       m
# 3              o         p                 k          s       u
# 4              o         e                 n          a       g
# ...          ...       ...               ...        ...     ...
# 8119           o         p                 b          c       l
# 8120           o         p                 b          v       l
# 8121           o         p                 b          c       l
# 8122           o         e                 w          v       l
# 8123           o         p                 o          c       l
#
# [8124 rows x 23 columns]

# %%
# Allow Pandas to show all columns in the table (Be Cautious here with 
# very large datasets, as this can take up a lot of memory if many 
# large tables are printed in a Notebook)

pd.set_option("display.max_columns", None)

#pd.set_option("display.max_columns", 20)

# %%
# Now all the table columns are displayed to the screen

df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color stalk-shape stalk-root  \
# 0               c         n          k           e          e
# 1               c         b          k           e          c
# 2               c         b          n           e          c
# 3               c         n          n           e          e
# 4               w         b          k           t          e
# ...           ...       ...        ...         ...        ...
# 8119            c         b          y           e          ?
# 8120            c         b          y           e          ?
# 8121            c         b          n           e          ?
# 8122            c         n          b           t          ?
# 8123            c         b          y           e          ?
#
#      stalk-surface-above-ring stalk-surface-below-ring stalk-color-above-ring  \
# 0                           s                        s                      w
# 1                           s                        s                      w
# 2                           s                        s                      w
# 3                           s                        s                      w
# 4                           s                        s                      w
# ...                       ...                      ...                    ...
# 8119                        s                        s                      o
# 8120                        s                        s                      o
# 8121                        s                        s                      o
# 8122                        s                        k                      w
# 8123                        s                        s                      o
#
#      stalk-color-below-ring veil-type veil-color ring-number ring-type  \
# 0                         w         p          w           o         p
# 1                         w         p          w           o         p
# 2                         w         p          w           o         p
# 3                         w         p          w           o         p
# 4                         w         p          w           o         e
# ...                     ...       ...        ...         ...       ...
# 8119                      o         p          o           o         p
# 8120                      o         p          n           o         p
# 8121                      o         p          o           o         p
# 8122                      w         p          w           o         e
# 8123                      o         p          o           o         p
#
#      spore-print-color population habitat
# 0                    k          s       u
# 1                    n          n       g
# 2                    n          n       m
# 3                    k          s       u
# 4                    n          a       g
# ...                ...        ...     ...
# 8119                 b          c       l
# 8120                 b          v       l
# 8121                 b          c       l
# 8122                 w          v       l
# 8123                 o          c       l
#
# [8124 rows x 23 columns]

# %%
# Look at the top and bottom of the dataframe

display(df.head(2))
display(df.tail(3))
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
#
#   gill-spacing gill-size gill-color stalk-shape stalk-root  \
# 0            c         n          k           e          e
# 1            c         b          k           e          c
#
#   stalk-surface-above-ring stalk-surface-below-ring stalk-color-above-ring  \
# 0                        s                        s                      w
# 1                        s                        s                      w
#
#   stalk-color-below-ring veil-type veil-color ring-number ring-type  \
# 0                      w         p          w           o         p
# 1                      w         p          w           o         p
#
#   spore-print-color population habitat
# 0                 k          s       u
# 1                 n          n       g
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color stalk-shape stalk-root  \
# 8121            c         b          n           e          ?
# 8122            c         n          b           t          ?
# 8123            c         b          y           e          ?
#
#      stalk-surface-above-ring stalk-surface-below-ring stalk-color-above-ring  \
# 8121                        s                        s                      o
# 8122                        s                        k                      w
# 8123                        s                        s                      o
#
#      stalk-color-below-ring veil-type veil-color ring-number ring-type  \
# 8121                      o         p          o           o         p
# 8122                      w         p          w           o         e
# 8123                      o         p          o           o         p
#
#      spore-print-color population habitat
# 8121                 b          c       l
# 8122                 w          v       l
# 8123                 o          c       l

# %%
# Use a grid system, .iloc[row #, column #], to locate the odor of the 2nd sample 

df.iloc[1,2]
# Out:
# 's'

# %%
# Use column names to get the cap-colour of the 5th sample

df["cap-color"][4]
# Out:
# 'g'

# %%
# Create an array from all the values in a column 
# Notation: df.iloc[rows, columns]
# df.iloc[:,:] = all the rows and all the columns

y = df.iloc[:,0:1]
y
# Out:
#      class
# 0        p
# 1        e
# 2        e
# 3        p
# 4        e
# ...    ...
# 8119     e
# 8120     e
# 8121     e
# 8122     p
# 8123     e
#
# [8124 rows x 1 columns]

# %%
# Get all column names

df.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
# count the number of rows in the dataset

num_total = len(df)
num_total
# Out:
# 8124

# %% [markdown]
# #### Grouping Data in a Dataframe

# %%
# Group-by is a very handy Pandas function for finding statistics for different categories in a column
# for example, count() will give the number of each value in a column that belongs to each group in the column stated.
# You can also get the mean, sum, etc of numerical columns

df.groupby(by = "class").count()
# Out:
#        cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# class
# e           4208         4208       4208     4208  4208             4208
# p           3916         3916       3916     3916  3916             3916
#
#        gill-spacing  gill-size  gill-color  stalk-shape  stalk-root  \
# class
# e              4208       4208        4208         4208        4208
# p              3916       3916        3916         3916        3916
#
#        stalk-surface-above-ring  stalk-surface-below-ring  \
# class
# e                          4208                      4208
# p                          3916                      3916
#
#        stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# class
# e                        4208                    4208       4208        4208
# p                        3916                    3916       3916        3916
#
#        ring-number  ring-type  spore-print-color  population  habitat
# class
# e             4208       4208               4208        4208     4208
# p             3916       3916               3916        3916     3916

# %%
# Group on multiple columns
df.groupby(["class",'odor']).count()
# Out:
#             cap-shape  cap-surface  cap-color  bruises  gill-attachment  \
# class odor
# e     a           400          400        400      400              400
#       l           400          400        400      400              400
#       n          3408         3408       3408     3408             3408
# p     c           192          192        192      192              192
#       f          2160         2160       2160     2160             2160
#       m            36           36         36       36               36
#       n           120          120        120      120              120
#       p           256          256        256      256              256
#       s           576          576        576      576              576
#       y           576          576        576      576              576
#
#             gill-spacing  gill-size  gill-color  stalk-shape  stalk-root  \
# class odor
# e     a              400        400         400          400         400
#       l              400        400         400          400         400
#       n             3408       3408        3408         3408        3408
# p     c              192        192         192          192         192
#       f             2160       2160        2160         2160        2160
#       m               36         36          36           36          36
#       n              120        120         120          120         120
#       p              256        256         256          256         256
#       s              576        576         576          576         576
#       y              576        576         576          576         576
#
#             stalk-surface-above-ring  stalk-surface-below-ring  \
# class odor
# e     a                          400                       400
#       l                          400                       400
#       n                         3408                      3408
# p     c                          192                       192
#       f                         2160                      2160
#       m                           36                        36
#       n                          120                       120
#       p                          256                       256
#       s                          576                       576
#       y                          576                       576
#
#             stalk-color-above-ring  stalk-color-below-ring  veil-type  \
# class odor
# e     a                        400                     400        400
#       l                        400                     400        400
#       n                       3408                    3408       3408
# p     c                        192                     192        192
#       f                       2160                    2160       2160
#       m                         36                      36         36
#       n                        120                     120        120
#       p                        256                     256        256
#       s                        576                     576        576
#       y                        576                     576        576
#
#             veil-color  ring-number  ring-type  spore-print-color  population  \
# class odor
# e     a            400          400        400                400         400
#       l            400          400        400                400         400
#       n           3408         3408       3408               3408        3408
# p     c            192          192        192                192         192
#       f           2160         2160       2160               2160        2160
#       m             36           36         36                 36          36
#       n            120          120        120                120         120
#       p            256          256        256                256         256
#       s            576          576        576                576         576
#       y            576          576        576                576         576
#
#             habitat
# class odor
# e     a         400
#       l         400
#       n        3408
# p     c         192
#       f        2160
#       m          36
#       n         120
#       p         256
#       s         576
#       y         576

# %%
# Filter on a column
df_edible = df[df['class'] == 'e']
num_edible = len(df_edible)

display(df_edible.head(3))
print(f"There are {num_edible} edible entires in the dataset out of {num_total} samples.")
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color stalk-shape stalk-root  \
# 1            c         b          k           e          c
# 2            c         b          n           e          c
# 4            w         b          k           t          e
#
#   stalk-surface-above-ring stalk-surface-below-ring stalk-color-above-ring  \
# 1                        s                        s                      w
# 2                        s                        s                      w
# 4                        s                        s                      w
#
#   stalk-color-below-ring veil-type veil-color ring-number ring-type  \
# 1                      w         p          w           o         p
# 2                      w         p          w           o         p
# 4                      w         p          w           o         e
#
#   spore-print-color population habitat
# 1                 n          n       g
# 2                 n          n       m
# 4                 n          a       g
# There are 4208 edible entires in the dataset out of 8124 samples.

# %%
# Filter on multiple conditions
# Use & for the AND condition, '|' for the OR condition 

df[(df['class'] == 'e') & (df['odor'] == 'n') | (df['habitat'] == 'g')]
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 1        e         x           s         y       t    a               f
# 4        e         x           s         g       f    n               f
# 5        e         x           y         y       t    a               f
# 8        p         x           y         w       t    p               f
# 10       e         x           y         y       t    l               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8115     e         x           s         n       f    n               a
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color stalk-shape stalk-root  \
# 1               c         b          k           e          c
# 4               w         b          k           t          e
# 5               c         b          n           e          c
# 8               c         n          p           e          e
# 10              c         b          g           e          c
# ...           ...       ...        ...         ...        ...
# 8115            c         b          y           e          ?
# 8119            c         b          y           e          ?
# 8120            c         b          y           e          ?
# 8121            c         b          n           e          ?
# 8123            c         b          y           e          ?
#
#      stalk-surface-above-ring stalk-surface-below-ring stalk-color-above-ring  \
# 1                           s                        s                      w
# 4                           s                        s                      w
# 5                           s                        s                      w
# 8                           s                        s                      w
# 10                          s                        s                      w
# ...                       ...                      ...                    ...
# 8115                        s                        s                      o
# 8119                        s                        s                      o
# 8120                        s                        s                      o
# 8121                        s                        s                      o
# 8123                        s                        s                      o
#
#      stalk-color-below-ring veil-type veil-color ring-number ring-type  \
# 1                         w         p          w           o         p
# 4                         w         p          w           o         e
# 5                         w         p          w           o         p
# 8                         w         p          w           o         p
# 10                        w         p          w           o         p
# ...                     ...       ...        ...         ...       ...
# 8115                      o         p          o           o         p
# 8119                      o         p          o           o         p
# 8120                      o         p          n           o         p
# 8121                      o         p          o           o         p
# 8123                      o         p          o           o         p
#
#      spore-print-color population habitat
# 1                    n          n       g
# 4                    n          a       g
# 5                    k          n       g
# 8                    k          v       g
# 10                   n          n       g
# ...                ...        ...     ...
# 8115                 o          v       l
# 8119                 b          c       l
# 8120                 b          v       l
# 8121                 b          c       l
# 8123                 o          c       l
#
# [4500 rows x 23 columns]

# %%
# Make a subset dataframe (note the double square brackets, case sensitive)
df_subset = df[['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
       'gill-attachment', 'gill-spacing',]]

# %%
# we created a 'copy' of the original table with the selected information
df_subset
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing
# 0               c
# 1               c
# 2               c
# 3               c
# 4               w
# ...           ...
# 8119            c
# 8120            c
# 8121            c
# 8122            c
# 8123            c
#
# [8124 rows x 8 columns]

# %% [markdown]
# ### Concatenate or Join Dataframes together

# %%
# Concat vertically (column names are matched)
pd.concat([df, df_subset], axis=0)
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color stalk-shape stalk-root  \
# 0               c         n          k           e          e
# 1               c         b          k           e          c
# 2               c         b          n           e          c
# 3               c         n          n           e          e
# 4               w         b          k           t          e
# ...           ...       ...        ...         ...        ...
# 8119            c       NaN        NaN         NaN        NaN
# 8120            c       NaN        NaN         NaN        NaN
# 8121            c       NaN        NaN         NaN        NaN
# 8122            c       NaN        NaN         NaN        NaN
# 8123            c       NaN        NaN         NaN        NaN
#
#      stalk-surface-above-ring stalk-surface-below-ring stalk-color-above-ring  \
# 0                           s                        s                      w
# 1                           s                        s                      w
# 2                           s                        s                      w
# 3                           s                        s                      w
# 4                           s                        s                      w
# ...                       ...                      ...                    ...
# 8119                      NaN                      NaN                    NaN
# 8120                      NaN                      NaN                    NaN
# 8121                      NaN                      NaN                    NaN
# 8122                      NaN                      NaN                    NaN
# 8123                      NaN                      NaN                    NaN
#
#      stalk-color-below-ring veil-type veil-color ring-number ring-type  \
# 0                         w         p          w           o         p
# 1                         w         p          w           o         p
# 2                         w         p          w           o         p
# 3                         w         p          w           o         p
# 4                         w         p          w           o         e
# ...                     ...       ...        ...         ...       ...
# 8119                    NaN       NaN        NaN         NaN       NaN
# 8120                    NaN       NaN        NaN         NaN       NaN
# 8121                    NaN       NaN        NaN         NaN       NaN
# 8122                    NaN       NaN        NaN         NaN       NaN
# 8123                    NaN       NaN        NaN         NaN       NaN
#
#      spore-print-color population habitat
# 0                    k          s       u
# 1                    n          n       g
# 2                    n          n       m
# 3                    k          s       u
# 4                    n          a       g
# ...                ...        ...     ...
# 8119               NaN        NaN     NaN
# 8120               NaN        NaN     NaN
# 8121               NaN        NaN     NaN
# 8122               NaN        NaN     NaN
# 8123               NaN        NaN     NaN
#
# [16248 rows x 23 columns]

# %%
# Use merge to join dataframes with a common column

# First dataframe
data1 = {'Country': ['USA', 'Canada', 'Brazil', 'India', 'China'],
         'Region': ['Americas', 'Americas', 'Americas', 'Asia', 'Asia']}
df1 = pd.DataFrame(data1)

# Second dataFrame 
data2 = {'Country': ['USA', 'Canada', 'Brazil', 'India', 'China'],
         'Population': [331002651, 37742154, 212559417, 1380004385, 1444216107],
         'Area (sq km)': [9833517, 9976140, 8515767, 3287263, 9596961]}
df2 = pd.DataFrame(data2)


# Merge the DataFrames based on the 'Country' column
merged_df =  pd.merge(df1,df2, on ='Country')

# Display the merged DataFrame
print("Merged DataFrame:")
merged_df
# Out:
# Merged DataFrame:
#   Country    Region  Population  Area (sq km)
# 0     USA  Americas   331002651       9833517
# 1  Canada  Americas    37742154       9976140
# 2  Brazil  Americas   212559417       8515767
# 3   India      Asia  1380004385       3287263
# 4   China      Asia  1444216107       9596961
